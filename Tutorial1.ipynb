# %% [markdown]
# ***scenario-1***

# %% [markdown]
# ***Managed catalog -Mmanaged schema -Managed table***

# %%
# %sql
create catalog Managed_catalog

# %%
# %sql
create schema Managed_catalog.managed_schema

# %%
# %sql
create table Managed_catalog.managed_schema.managed_table (id int, name string);
    
insert into Managed_catalog.managed_schema.managed_table values (1, 'John'), (2, 'Jane');
    
select * from Managed_catalog.managed_schema.managed_table
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th></tr></thead><tbody><tr><td>1</td><td>John</td></tr><tr><td>2</td><td>Jane</td></tr></tbody></table></div>

# %% [markdown]
# ***MAnaged catalog - Managed schema - Externaltable***

# %%
# %sql
create table Managed_catalog.managed_schema.external_Table (id int, name string) using DELTA;

# %%
# %sql
create external table managed_catalog.managed_schema.external_table1 (id int, name string) using DELTA
location 'abfss://mymetastore@janadfstorage.dfs.core.windows.net/external_table1/';

# %%
# %sql
insert into managed_catalog.managed_schema.external_table1 values (1, 'John'), (2, 'Jane');
    
select * from managed_catalog.managed_schema.external_table1
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th></tr></thead><tbody><tr><td>1</td><td>John</td></tr><tr><td>2</td><td>Jane</td></tr></tbody></table></div>

# %% [markdown]
# ###Querying files using select###

# %%
# %sql 
select * from delta.`abfss://mymetastore@janadfstorage.dfs.core.windows.net/external_table1` where id = 1;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th></tr></thead><tbody><tr><td>1</td><td>John</td></tr></tbody></table></div>

# %% [markdown]
# ###Creating Views###

# %%
# %sql
CREATE VIEW Managed_catalog.managed_schema.External_view1 AS select * from delta.`abfss://mymetastore@janadfstorage.dfs.core.windows.net/external_table1` where id = 1;

# %% [markdown]
# ###creating temp view###

# %%
# %sql
CREATE or REPLACE TEMP VIEW temp_view1 AS select * from delta.`abfss://mymetastore@janadfstorage.dfs.core.windows.net/external_table1` where id = 1;
